# %%
#practice cca implementation
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import kcca
import random

random.seed(30)
tx = np.random.random((100,1))

# %%
tx2 = np.sin(3*tx)
x = np.hstack((tx,tx2))
ty = np.exp(tx/4)*np.cos(2*tx)
ty2 = np.exp(tx/4)*np.sin(2*tx)
y = np.hstack((ty,ty2))

# %%
tradcca = kcca.KCCA(kernelcca = False, reg = 0., numCC = 2)
tradcca.train([x, y])
fig = plt.figure()
plt.scatter(tradcca.comps_[0][:,0],tradcca.comps_[1][:,0])
fig = plt.figure()
plt.scatter(tradcca.comps_[0][:,1],tradcca.comps_[1][:,1])

# %%
tradcca.cancorrs_
# Out:
# array([0.99863923, 0.78197038])

# %%
gauskcca = kcca.KCCA(kernelcca = True, ktype ="gaussian", reg = 0.0001, numCC = 2, gausigma=2.0)
gauskcca.train([x, y])

# %%
fig = plt.figure()
plt.scatter(gauskcca.comps_[0][:,0],gauskcca.comps_[1][:,0])
fig = plt.figure()
plt.scatter(gauskcca.comps_[0][:,1],gauskcca.comps_[1][:,1])

# %%
gauskcca.cancorrs_
# Out:
# array([0.99278842, 0.99894752])

# %%
#polynomial kernel implementation
polykcca = kcca.KCCA(ktype ="poly", reg = 0.0001, numCC = 2, degree = 6)
polykcca.train([x, y])
fig = plt.figure()
plt.scatter(polykcca.comps_[0][:,0],polykcca.comps_[1][:,0])
fig = plt.figure()
plt.scatter(polykcca.comps_[0][:,1],polykcca.comps_[1][:,1])
