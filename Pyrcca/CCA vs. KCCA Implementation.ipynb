# %%
#practice cca implementation
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import rcca
import random

random.seed(30)
tx = np.random.random((100,1))

# %%
tx2 = np.sin(3*tx)
x = np.hstack((tx,tx2))
ty = np.exp(tx/4)*np.cos(2*tx)
ty2 = np.exp(tx/4)*np.sin(2*tx)
y = np.hstack((ty,ty2))

# %%
tradcca = rcca.CCA(kernelcca = False, reg = 0., numCC = 2)
tradcca.train([x, y])
fig = plt.figure()
plt.scatter(tradcca.comps_[0][:,0],tradcca.comps_[1][:,0])
fig = plt.figure()
plt.scatter(tradcca.comps_[0][:,1],tradcca.comps_[1][:,1])
# Out:
# Training CCA, kernel = None, regularization = 0.0000, 2 components

# %%
tradcca.cancorrs_
# Out:
# array([0.99922895, 0.76123993])

# %%
gauskcca = rcca.CCA(kernelcca = True, ktype ="gaussian", reg = 0.0001, numCC = 2)
gauskcca.train([x, y])
# Out:
# Training CCA, kernel = gaussian, regularization = 0.0001, 2 components

# %%
fig = plt.figure()
plt.scatter(gauskcca.comps_[0][:,0],gauskcca.comps_[1][:,0])
fig = plt.figure()
plt.scatter(gauskcca.comps_[0][:,1],gauskcca.comps_[1][:,1])

# %%
gauskcca.cancorrs_
# Out:
# array([0.9863317 , 0.96608999])

# %%
polykcca = rcca.CCA(kernelcca = True, ktype ="poly", reg = 0.0001, numCC = 2, degree=4)
polykcca.train([x, y])
fig = plt.figure()
plt.scatter(polykcca.comps_[0][:,0],polykcca.comps_[1][:,0])
fig = plt.figure()
plt.scatter(polykcca.comps_[0][:,1],polykcca.comps_[1][:,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e195e074e0de> in <module>()
# ----> 1 polykcca = rcca.CCA(kernelcca = True, ktype ="poly", reg = 0.0001, numCC = 2, degree=4)
#       2 polykcca.train([x, y])
#       3 fig = plt.figure()
#       4 plt.scatter(polykcca.comps_[0][:,0],polykcca.comps_[1][:,0])
#       5 fig = plt.figure()
#
# TypeError: __init__() got an unexpected keyword argument 'degree'
