# %%
# %matplotlib inline
import sys
import matplotlib.pyplot as plt
sys.path.append("..")

from datasets.base import load_UCImultifeature

data = load_UCImultifeature()

# %%
views = data[0]
view_1 = views[0]
view_2 = views[1]
view_3 = views[2]
view_4 = views[3]
view_5 = views[4]
view_6 = views[5]

# %%
kcca_l_2 = kcca.KCCA(ktype ="linear", reg = 0.0001, numCC = 2)
kcca_l_2.train([view_1, view_5])

# %%
fig = plt.figure()
plt.scatter(kcca_l_2.comps_[0][:,0],kcca_l_2.comps_[1][:,0])
fig = plt.figure()
plt.scatter(kcca_l_2.comps_[0][:,1],kcca_l_2.comps_[1][:,1])

# %%
kcca_l_2.cancorrs_
# Out:
# array([0.94517376, 0.87106874])

# %%
'''
kcca_l_3 = kcca.KCCA(ktype ="linear", reg = 0.0001, numCC = 3)
kcca_l_3.train([view_1, view_2, view_3])
'''

# %%
from mpl_toolkits import mplot3d

# %%
'''
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(kcca_l_3.comps_[0][:,0],kcca_l_3.comps_[1][:,0],kcca_l_3.comps_[2][:,0])
'''

# %%
'''
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(kcca_l_3.comps_[0][:,1],kcca_l_3.comps_[1][:,1],kcca_l_3.comps_[2][:,1])
'''

# %%
'''
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(kcca_l_3.comps_[0][:,2],kcca_l_3.comps_[1][:,2],kcca_l_3.comps_[2][:,2])
'''

# %%
'''
kcca_l.cancorrs_
'''
# Out:
# array([[[0.        , 0.9240088 , 0.89918858],
#         [0.        , 0.        , 0.96466196],
#         [0.        , 0.        , 0.        ]],
#
#        [[0.        , 0.89057955, 0.88056713],
#         [0.        , 0.        , 0.93479511],
#         [0.        , 0.        , 0.        ]],
#
#        [[0.        , 0.76698034, 0.77858525],
#         [0.        , 0.        , 0.95907641],
#         [0.        , 0.        , 0.        ]]])

# %%
kcca_p = kcca.KCCA(ktype ="poly", reg = 0.0001, numCC = 2, degree = 2)
kcca_p.train([view_1, view_2])

# %%
fig = plt.figure()
plt.scatter(kcca_p.comps_[0][:,0],kcca_p.comps_[1][:,0])
fig = plt.figure()
plt.scatter(kcca_p.comps_[0][:,1],kcca_p.comps_[1][:,1])

# %%
kcca_p.cancorrs_
# Out:
# array([0.1784919 , 0.41199794])

# %%
kcca_p3 = kcca.KCCA(ktype ="poly", reg = 0.0001, numCC = 2, degree = 3)
kcca_p3.train([view_1, view_2])

# %%
fig = plt.figure()
plt.scatter(kcca_p3.comps_[0][:,0],kcca_p3.comps_[1][:,0])
fig = plt.figure()
plt.scatter(kcca_p3.comps_[0][:,1],kcca_p3.comps_[1][:,1])

# %%
kcca_p3.cancorrs_
# Out:
# array([-0.2864376 ,  0.26655855])

# %%
kcca_p4 = kcca.KCCA(ktype ="poly", reg = 0.0001, numCC = 2, degree = 4)
kcca_p4.train([view_1, view_2])

# %%
fig = plt.figure()
plt.scatter(kcca_p4.comps_[0][:,0],kcca_p4.comps_[1][:,0])
fig = plt.figure()
plt.scatter(kcca_p4.comps_[0][:,1],kcca_p4.comps_[1][:,1])

# %%
kcca_p3.cancorrs_
# Out:
# array([-0.2864376 ,  0.26655855])

# %%
kcca_g = kcca.KCCA(ktype ="gaussian", reg = 0.0001, numCC = 2, gausigma=2.0)
kcca_g.train([view_1, view_2])

# %%
fig = plt.figure()
plt.scatter(kcca_g.comps_[0][:,0],kcca_g.comps_[1][:,0])
fig = plt.figure()
plt.scatter(kcca_g.comps_[0][:,1],kcca_g.comps_[1][:,1])

# %%
kcca_g.cancorrs_
# Out:
# array([0.21365646, 0.70689663])

# %%
kcca_g1 = kcca.KCCA(ktype ="gaussian", reg = 0.0001, numCC = 2, gausigma=1.0)
kcca_g1.train([view_1, view_2])

# %%
fig = plt.figure()
plt.scatter(kcca_g1.comps_[0][:,0],kcca_g1.comps_[1][:,0])
fig = plt.figure()
plt.scatter(kcca_g1.comps_[0][:,1],kcca_g1.comps_[1][:,1])

# %%
kcca_g1.cancorrs_
# Out:
# array([0.20255824, 0.75611039])

# %%
kcca_g025 = kcca.KCCA(ktype ="gaussian", reg = 0.0001, numCC = 2, gausigma=0.25)
kcca_g025.train([view_1, view_2])

# %%
fig = plt.figure()
plt.scatter(kcca_g025.comps_[0][:,0],kcca_g025.comps_[1][:,0])
fig = plt.figure()
plt.scatter(kcca_g025.comps_[0][:,1],kcca_g025.comps_[1][:,1])

# %%
kcca_g025.cancorrs_
# Out:
# array([0.19872405, 0.75162478])
